# %%
import io
from textwrap3 import wrap

def formatting(input):
    with io.open(input, 'rt', encoding='utf8', errors='ignore') as f:
        raw = f.read()
        f.close()
#     wrapped = ''
    x = wrap(raw, 40)
    for i in range(len(x)):
        print(x[i].center(100))

formatting("output/v2-101-best.txt")

# string_centered = string.center(79, '.')
# string_centered
# Out:
#                                 It is now common practice for these
#                                  athletes to sit for long intervals
#                                before the competition, and I remember
#                                the first time that I went.  The woman
#                                in the fifties  She looked young and I
#                                was old enough to take her place.  and
#                                the dog for all that he was  She then
#                                began to run The whole idea was that I
#                                might be taken in for questioning, so
#                                that the first impression I had of her
#                               disappeared.  and the old fool  She was
#                                 not my first choice, but perhaps my
#                               last, since I had never made a decision
#                                since I was a child.  and the old man
# ...
